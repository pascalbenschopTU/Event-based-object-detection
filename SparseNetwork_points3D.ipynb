# %%
from eventvision import read_dataset, read_annotation

import os
import cv2
import glob
import time
import numpy as np
import contextlib
import torch.cuda.amp
from sklearn.model_selection import train_test_split

import spconv.pytorch as spconv
import torch
import torch.optim as optim
from torch import nn
import torch.nn.functional as F

from BoundingBoxRegressionUtils import parse_partial_dataset, parse_random_dataset, torch_iou


POINTS = 500
# Out:
# Event-based vision module imported

# %%
def getData(filename):
    td = read_dataset(filename)
    
    width = td.width
    height = td.height
    
    points = np.column_stack((td.data.x[:POINTS], td.data.y[:POINTS], td.data.ts[:POINTS] / 1000))
    
    return width, height, np.array(points).reshape(POINTS, 3, 1)

def getAnnotation(filename):
    data = read_annotation(filename)
    minX = min(data[0])
    maxX = max(data[0])
    minY = min(data[1])
    maxY = max(data[1])
    
    return minX, minY, maxX, maxY

# %%
def train(args, model, device, train_loader, optimizer, epoch):
    model.train()
    correct = 0
    amp_ctx = contextlib.nullcontext()
    if args.fp16:
        amp_ctx = torch.cuda.amp.autocast()
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        with amp_ctx:
            output = model(data)
            loss = F.mse_loss(output, target)
            loss.backward()
            optimizer.step()
            
            correct += torch.sum(torch_iou(output[:, -4:], target[:, -4:]))
            
    return correct / len(train_loader.dataset)

def test(args, model, device, test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    amp_ctx = contextlib.nullcontext()
    if args.fp16:
        amp_ctx = torch.cuda.amp.autocast()

    with torch.no_grad():
        for data, target in test_loader:

            data, target = data.to(device), target.to(device)
            with amp_ctx:

                output = model(data)
            test_loss += F.mse_loss(output, target, reduction='sum').item() # sum up batch loss
            
            correct += torch.sum(torch_iou(output[:, -4:], target[:, -4:]))
            

    test_loss /= len(test_loader.dataset)

    
    return correct / len(test_loader.dataset)

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.net = spconv.SparseSequential(
            spconv.SparseConv2d(1, 16, 5, stride=1, padding=2),
            nn.LeakyReLU(0.1),
            spconv.SparseMaxPool2d(2, 2),
            
            spconv.SparseConv2d(16, 32, 5, stride=1, padding=2),
            nn.LeakyReLU(0.1),
            spconv.SparseMaxPool2d(2, 2, 1),
            
            spconv.SparseConv2d(32, 64, 5, stride=1, padding=2),
            nn.LeakyReLU(0.1),
            spconv.SparseMaxPool2d(2, 2, 1),
            
            spconv.SparseConv2d(64, 128, 5, stride=1, padding=2),
            nn.LeakyReLU(0.1),
            spconv.SparseMaxPool2d(2, 2, (0,1)),
            
            spconv.SparseConv2d(128, 256, 5, stride=1, padding=2),
            nn.LeakyReLU(0.1),
            spconv.SparseMaxPool2d(2, 2, (0,1)),
            
            spconv.ToDense(),
            nn.Flatten(1,-1),
            nn.Dropout(p=0.2),
            nn.Linear(4096, 2048),
            nn.Linear(2048, 1024),
            nn.Linear(1024, 8),
        )

    def forward(self, x: torch.Tensor):
        x = spconv.SparseConvTensor.from_dense(x.reshape(-1, POINTS, 3, 1))
        y =  self.net(x)
        
        return y

# %%
X_train, X_test, y_train, y_test = parse_partial_dataset(getData, getAnnotation)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

train_loader = torch.utils.data.DataLoader(
    [[X_train[i], y_train[i]] for i in range(len(X_train))], shuffle=False, batch_size=40)
test_loader = torch.utils.data.DataLoader(
    [[X_test[i], y_test[i]] for i in range(len(X_test))], shuffle=False, batch_size=40)

args = lambda: None
args.fp16 = True
args.lr = 0.001
args.log_interval = 50

device = torch.device("cuda:0") if torch.cuda.is_available() else torch.device("cpu")
print(device)

def makeTestData():
    testData = []
    
    for i in range(10): 
        X_test, y_test = parse_random_dataset(getData, getAnnotation, True)
        test_loader = torch.utils.data.DataLoader(
            [[X_test[i], y_test[i]] for i in range(len(X_test))], shuffle=False, batch_size=40)
        
        testData.append(test_loader)
        
    return testData

def testTiming(model, testData):
    total_time = 0.0
    total_acc = 0.0
    for i in range(10): 
        test_loader = testData[i]

        testing_time = time.time()

        iou = test(args, model, device, test_loader)

        time_taken = time.time()  - testing_time

        total_time += time_taken
        total_acc += iou

        print("\tFor this mini round, time: ", time_taken, " iou ", iou)

    avg_time = total_time / 10
    avg_acc = total_acc / 10
    
    print("Time on avg: ", avg_time, " IOU on avg: ", avg_acc)
    
    return avg_time, avg_acc

def trainModel():
    model = Net().to(device)
    optimizer = optim.Adam(model.parameters(), lr=args.lr)
    
    train_start_time = time.process_time()

    for epoch in range(0, 40):
        train(args, model, device, train_loader, optimizer, epoch)

    train_time = time.process_time() - train_start_time
    
    print("Training done!  " + str(train_time))
    
    return train_time, model

def getResults():
    testData = makeTestData()
    
    train_timing_results = np.empty(20)
    test_timing_results = np.empty(20)
    test_acc_results = np.empty(20)

    for i in range(20):
        print("Round ", i)

        train_time, model = trainModel()
        train_timing_results[i] = train_time
        
        test_time, test_acc = testTiming(model, testData)
        test_timing_results[i] = test_time
        test_acc_results[i] = test_acc

    print("\n\nTesting done!\n")

    print("Training time: ", np.mean(train_timing_results))
    print("Testing time: ", np.mean(test_timing_results))
    print("Testing acc: ", np.mean(test_acc_results))
    
    return train_timing_results, test_timing_results, test_acc_results

getResults()
# Out:
# cuda:0
# Round  0
# Training done!  29.09375
# 	For this mini round, time:  0.3539755344390869  iou  tensor(0.7037, device='cuda:0')
# 	For this mini round, time:  0.37800025939941406  iou  tensor(0.7095, device='cuda:0')
# 	For this mini round, time:  0.36500120162963867  iou  tensor(0.7062, device='cuda:0')
# 	For this mini round, time:  0.3690226078033447  iou  tensor(0.7096, device='cuda:0')
# 	For this mini round, time:  0.37302470207214355  iou  tensor(0.7147, device='cuda:0')
# 	For this mini round, time:  0.39397525787353516  iou  tensor(0.7109, device='cuda:0')
# 	For this mini round, time:  0.39299917221069336  iou  tensor(0.7164, device='cuda:0')
# 	For this mini round, time:  0.3900003433227539  iou  tensor(0.7054, device='cuda:0')
# 	For this mini round, time:  0.4239990711212158  iou  tensor(0.7100, device='cuda:0')
# 	For this mini round, time:  0.41499948501586914  iou  tensor(0.7136, device='cuda:0')
# Time on avg:  0.3854997634887695  IOU on avg:  tensor(0.7100, device='cuda:0')
# Round  1
# Training done!  25.4375
# 	For this mini round, time:  0.37999987602233887  iou  tensor(0.6828, device='cuda:0')
# 	For this mini round, time:  0.3620278835296631  iou  tensor(0.6870, device='cuda:0')
# 	For this mini round, time:  0.3640017509460449  iou  tensor(0.6836, device='cuda:0')
# 	For this mini round, time:  0.3769998550415039  iou  tensor(0.6882, device='cuda:0')
# 	For this mini round, time:  0.37599897384643555  iou  tensor(0.6932, device='cuda:0')
# 	For this mini round, time:  0.41300082206726074  iou  tensor(0.6881, device='cuda:0')
# 	For this mini round, time:  0.40200018882751465  iou  tensor(0.6943, device='cuda:0')
# 	For this mini round, time:  0.4199988842010498  iou  tensor(0.6843, device='cuda:0')
# 	For this mini round, time:  0.4090001583099365  iou  tensor(0.6847, device='cuda:0')
# 	For this mini round, time:  0.4379699230194092  iou  tensor(0.6823, device='cuda:0')
# Time on avg:  0.3940998315811157  IOU on avg:  tensor(0.6868, device='cuda:0')
# Round  2
# Training done!  25.65625
# 	For this mini round, time:  0.37097644805908203  iou  tensor(0.7207, device='cuda:0')
# 	For this mini round, time:  0.3469986915588379  iou  tensor(0.7256, device='cuda:0')
# 	For this mini round, time:  0.35000014305114746  iou  tensor(0.7215, device='cuda:0')
# 	For this mini round, time:  0.3740274906158447  iou  tensor(0.7264, device='cuda:0')
# 	For this mini round, time:  0.3749988079071045  iou  tensor(0.7342, device='cuda:0')
# 	For this mini round, time:  0.41400980949401855  iou  tensor(0.7238, device='cuda:0')
# 	For this mini round, time:  0.4029719829559326  iou  tensor(0.7281, device='cuda:0')
# 	For this mini round, time:  0.40199995040893555  iou  tensor(0.7225, device='cuda:0')
# 	For this mini round, time:  0.4270017147064209  iou  tensor(0.7251, device='cuda:0')
# 	For this mini round, time:  0.4219987392425537  iou  tensor(0.7260, device='cuda:0')
# Time on avg:  0.3884983777999878  IOU on avg:  tensor(0.7254, device='cuda:0')
# Round  3
# Training done!  25.59375
# 	For this mini round, time:  0.3700287342071533  iou  tensor(0.7193, device='cuda:0')
# 	For this mini round, time:  0.34902358055114746  iou  tensor(0.7252, device='cuda:0')
# 	For this mini round, time:  0.36998867988586426  iou  tensor(0.7201, device='cuda:0')
# 	For this mini round, time:  0.3639993667602539  iou  tensor(0.7239, device='cuda:0')
# 	For this mini round, time:  0.3700263500213623  iou  tensor(0.7315, device='cuda:0')
# 	For this mini round, time:  0.39397597312927246  iou  tensor(0.7237, device='cuda:0')
# 	For this mini round, time:  0.40599989891052246  iou  tensor(0.7261, device='cuda:0')
# 	For this mini round, time:  0.41499948501586914  iou  tensor(0.7181, device='cuda:0')
# 	For this mini round, time:  0.4029998779296875  iou  tensor(0.7227, device='cuda:0')
# 	For this mini round, time:  0.4150261878967285  iou  tensor(0.7250, device='cuda:0')
# Time on avg:  0.3856068134307861  IOU on avg:  tensor(0.7236, device='cuda:0')
# Round  4
# Training done!  25.59375
# 	For this mini round, time:  0.3539762496948242  iou  tensor(0.7086, device='cuda:0')
# 	For this mini round, time:  0.36200785636901855  iou  tensor(0.7136, device='cuda:0')
# 	For this mini round, time:  0.36699724197387695  iou  tensor(0.7138, device='cuda:0')
# 	For this mini round, time:  0.37199997901916504  iou  tensor(0.7164, device='cuda:0')
# 	For this mini round, time:  0.37599992752075195  iou  tensor(0.7181, device='cuda:0')
# 	For this mini round, time:  0.39601731300354004  iou  tensor(0.7151, device='cuda:0')
# 	For this mini round, time:  0.39699792861938477  iou  tensor(0.7173, device='cuda:0')
# 	For this mini round, time:  0.4290006160736084  iou  tensor(0.7080, device='cuda:0')
# 	For this mini round, time:  0.41899991035461426  iou  tensor(0.7124, device='cuda:0')
# 	For this mini round, time:  0.4210238456726074  iou  tensor(0.7120, device='cuda:0')
# Time on avg:  0.38930208683013917  IOU on avg:  tensor(0.7135, device='cuda:0')
# Round  5
# Training done!  25.546875
# 	For this mini round, time:  0.3779754638671875  iou  tensor(0.6825, device='cuda:0')
# 	For this mini round, time:  0.3600010871887207  iou  tensor(0.6881, device='cuda:0')
# 	For this mini round, time:  0.37603068351745605  iou  tensor(0.6817, device='cuda:0')
# 	For this mini round, time:  0.35799431800842285  iou  tensor(0.6901, device='cuda:0')
# 	For this mini round, time:  0.37400007247924805  iou  tensor(0.6963, device='cuda:0')
# 	For this mini round, time:  0.4029691219329834  iou  tensor(0.6928, device='cuda:0')
# 	For this mini round, time:  0.4220001697540283  iou  tensor(0.6971, device='cuda:0')
# 	For this mini round, time:  0.4150235652923584  iou  tensor(0.6819, device='cuda:0')
# 	For this mini round, time:  0.4139986038208008  iou  tensor(0.6861, device='cuda:0')
# 	For this mini round, time:  0.4100072383880615  iou  tensor(0.6858, device='cuda:0')
# Time on avg:  0.39100003242492676  IOU on avg:  tensor(0.6882, device='cuda:0')
# Round  6
# Training done!  25.640625
# 	For this mini round, time:  0.36797285079956055  iou  tensor(0.7296, device='cuda:0')
# 	For this mini round, time:  0.3639824390411377  iou  tensor(0.7326, device='cuda:0')
# 	For this mini round, time:  0.3670003414154053  iou  tensor(0.7273, device='cuda:0')
# 	For this mini round, time:  0.359999418258667  iou  tensor(0.7326, device='cuda:0')
# 	For this mini round, time:  0.3860321044921875  iou  tensor(0.7395, device='cuda:0')
# 	For this mini round, time:  0.4120008945465088  iou  tensor(0.7357, device='cuda:0')
# 	For this mini round, time:  0.41499876976013184  iou  tensor(0.7338, device='cuda:0')
# 	For this mini round, time:  0.4040253162384033  iou  tensor(0.7280, device='cuda:0')
# 	For this mini round, time:  0.4320244789123535  iou  tensor(0.7341, device='cuda:0')
# 	For this mini round, time:  0.4269986152648926  iou  tensor(0.7324, device='cuda:0')
# Time on avg:  0.3935035228729248  IOU on avg:  tensor(0.7326, device='cuda:0')
# Round  7
# Training done!  25.5
# 	For this mini round, time:  0.3809990882873535  iou  tensor(0.6939, device='cuda:0')
# 	For this mini round, time:  0.3580000400543213  iou  tensor(0.6983, device='cuda:0')
# 	For this mini round, time:  0.368999719619751  iou  tensor(0.6961, device='cuda:0')
# 	For this mini round, time:  0.35003161430358887  iou  tensor(0.6990, device='cuda:0')
# 	For this mini round, time:  0.35900092124938965  iou  tensor(0.7125, device='cuda:0')
# 	For this mini round, time:  0.42103075981140137  iou  tensor(0.6986, device='cuda:0')
# 	For this mini round, time:  0.40804052352905273  iou  tensor(0.7032, device='cuda:0')
# 	For this mini round, time:  0.4040248394012451  iou  tensor(0.6952, device='cuda:0')
# 	For this mini round, time:  0.39803004264831543  iou  tensor(0.6992, device='cuda:0')
# 	For this mini round, time:  0.4119987487792969  iou  tensor(0.7008, device='cuda:0')
# Time on avg:  0.38601562976837156  IOU on avg:  tensor(0.6997, device='cuda:0')
# Round  8
# Training done!  25.96875
# 	For this mini round, time:  0.36902379989624023  iou  tensor(0.6756, device='cuda:0')
# 	For this mini round, time:  0.3599998950958252  iou  tensor(0.6770, device='cuda:0')
# 	For this mini round, time:  0.3680083751678467  iou  tensor(0.6787, device='cuda:0')
# 	For this mini round, time:  0.37000155448913574  iou  tensor(0.6718, device='cuda:0')
# 	For this mini round, time:  0.39999961853027344  iou  tensor(0.6843, device='cuda:0')
# 	For this mini round, time:  0.41697072982788086  iou  tensor(0.6769, device='cuda:0')
# 	For this mini round, time:  0.38300037384033203  iou  tensor(0.6772, device='cuda:0')
# 	For this mini round, time:  0.4010004997253418  iou  tensor(0.6758, device='cuda:0')
# 	For this mini round, time:  0.40200090408325195  iou  tensor(0.6740, device='cuda:0')
# 	For this mini round, time:  0.3880007266998291  iou  tensor(0.6750, device='cuda:0')
# Time on avg:  0.3858006477355957  IOU on avg:  tensor(0.6766, device='cuda:0')
# Round  9
# Training done!  25.515625
# 	For this mini round, time:  0.3679993152618408  iou  tensor(0.6991, device='cuda:0')
# 	For this mini round, time:  0.36503076553344727  iou  tensor(0.6990, device='cuda:0')
# 	For this mini round, time:  0.3550233840942383  iou  tensor(0.7000, device='cuda:0')
# 	For this mini round, time:  0.35899949073791504  iou  tensor(0.7016, device='cuda:0')
# 	For this mini round, time:  0.3810005187988281  iou  tensor(0.7137, device='cuda:0')
# 	For this mini round, time:  0.42099928855895996  iou  tensor(0.7010, device='cuda:0')
# 	For this mini round, time:  0.3969995975494385  iou  tensor(0.7022, device='cuda:0')
# 	For this mini round, time:  0.40000033378601074  iou  tensor(0.6903, device='cuda:0')
# 	For this mini round, time:  0.417996883392334  iou  tensor(0.7039, device='cuda:0')
# 	For this mini round, time:  0.4200000762939453  iou  tensor(0.6995, device='cuda:0')
# Time on avg:  0.3884049654006958  IOU on avg:  tensor(0.7010, device='cuda:0')
# Round  10
# Training done!  25.484375
# 	For this mini round, time:  0.3659992218017578  iou  tensor(0.6879, device='cuda:0')
# 	For this mini round, time:  0.3649709224700928  iou  tensor(0.6933, device='cuda:0')
# 	For this mini round, time:  0.3689696788787842  iou  tensor(0.6904, device='cuda:0')
# 	For this mini round, time:  0.365999698638916  iou  tensor(0.6955, device='cuda:0')
# 	For this mini round, time:  0.3720252513885498  iou  tensor(0.6975, device='cuda:0')
# 	For this mini round, time:  0.39799952507019043  iou  tensor(0.6960, device='cuda:0')
# 	For this mini round, time:  0.425997257232666  iou  tensor(0.6909, device='cuda:0')
# 	For this mini round, time:  0.41300082206726074  iou  tensor(0.6914, device='cuda:0')
# 	For this mini round, time:  0.4250006675720215  iou  tensor(0.6948, device='cuda:0')
# 	For this mini round, time:  0.4290001392364502  iou  tensor(0.6903, device='cuda:0')
# Time on avg:  0.39289631843566897  IOU on avg:  tensor(0.6928, device='cuda:0')
# Round  11
# Training done!  25.84375
# 	For this mini round, time:  0.35697507858276367  iou  tensor(0.6959, device='cuda:0')
# 	For this mini round, time:  0.39299893379211426  iou  tensor(0.7041, device='cuda:0')
# 	For this mini round, time:  0.37999749183654785  iou  tensor(0.6955, device='cuda:0')
# 	For this mini round, time:  0.37400031089782715  iou  tensor(0.6989, device='cuda:0')
# 	For this mini round, time:  0.37199974060058594  iou  tensor(0.7083, device='cuda:0')
# 	For this mini round, time:  0.40799999237060547  iou  tensor(0.7024, device='cuda:0')
# 	For this mini round, time:  0.4139900207519531  iou  tensor(0.7030, device='cuda:0')
# 	For this mini round, time:  0.4009873867034912  iou  tensor(0.6920, device='cuda:0')
# 	For this mini round, time:  0.41602349281311035  iou  tensor(0.7025, device='cuda:0')
# 	For this mini round, time:  0.4479990005493164  iou  tensor(0.6998, device='cuda:0')
# Time on avg:  0.39629714488983153  IOU on avg:  tensor(0.7002, device='cuda:0')
# Round  12
# Training done!  25.75
# 	For this mini round, time:  0.3559854030609131  iou  tensor(0.7195, device='cuda:0')
# 	For this mini round, time:  0.35500168800354004  iou  tensor(0.7241, device='cuda:0')
# 	For this mini round, time:  0.3570282459259033  iou  tensor(0.7222, device='cuda:0')
# 	For this mini round, time:  0.3629720211029053  iou  tensor(0.7253, device='cuda:0')
# 	For this mini round, time:  0.37399935722351074  iou  tensor(0.7344, device='cuda:0')
# 	For this mini round, time:  0.3969533443450928  iou  tensor(0.7231, device='cuda:0')
# 	For this mini round, time:  0.40400004386901855  iou  tensor(0.7284, device='cuda:0')
# 	For this mini round, time:  0.41497063636779785  iou  tensor(0.7196, device='cuda:0')
# 	For this mini round, time:  0.4130222797393799  iou  tensor(0.7275, device='cuda:0')
# 	For this mini round, time:  0.4160008430480957  iou  tensor(0.7229, device='cuda:0')
# Time on avg:  0.38499338626861573  IOU on avg:  tensor(0.7247, device='cuda:0')
# Round  13
# Training done!  25.875
# 	For this mini round, time:  0.37297558784484863  iou  tensor(0.7170, device='cuda:0')
# 	For this mini round, time:  0.3689992427825928  iou  tensor(0.7230, device='cuda:0')
# 	For this mini round, time:  0.3660006523132324  iou  tensor(0.7167, device='cuda:0')
# 	For this mini round, time:  0.36099982261657715  iou  tensor(0.7231, device='cuda:0')
# 	For this mini round, time:  0.3729996681213379  iou  tensor(0.7284, device='cuda:0')
# 	For this mini round, time:  0.39100050926208496  iou  tensor(0.7237, device='cuda:0')
# 	For this mini round, time:  0.40000057220458984  iou  tensor(0.7247, device='cuda:0')
# 	For this mini round, time:  0.3930323123931885  iou  tensor(0.7136, device='cuda:0')
# 	For this mini round, time:  0.4180002212524414  iou  tensor(0.7228, device='cuda:0')
# 	For this mini round, time:  0.42799997329711914  iou  tensor(0.7223, device='cuda:0')
# Time on avg:  0.3872008562088013  IOU on avg:  tensor(0.7215, device='cuda:0')
# Round  14
# Training done!  25.515625
# 	For this mini round, time:  0.3579981327056885  iou  tensor(0.6498, device='cuda:0')
# 	For this mini round, time:  0.36999988555908203  iou  tensor(0.6506, device='cuda:0')
# 	For this mini round, time:  0.3579988479614258  iou  tensor(0.6510, device='cuda:0')
# 	For this mini round, time:  0.36600160598754883  iou  tensor(0.6540, device='cuda:0')
# 	For this mini round, time:  0.35500001907348633  iou  tensor(0.6614, device='cuda:0')
# 	For this mini round, time:  0.39799952507019043  iou  tensor(0.6604, device='cuda:0')
# 	For this mini round, time:  0.3940005302429199  iou  tensor(0.6530, device='cuda:0')
# 	For this mini round, time:  0.39999890327453613  iou  tensor(0.6450, device='cuda:0')
# 	For this mini round, time:  0.42699337005615234  iou  tensor(0.6538, device='cuda:0')
# 	For this mini round, time:  0.4149644374847412  iou  tensor(0.6576, device='cuda:0')
# Time on avg:  0.3840955257415771  IOU on avg:  tensor(0.6537, device='cuda:0')
# Round  15
# Training done!  25.546875
# 	For this mini round, time:  0.3710002899169922  iou  tensor(0.7127, device='cuda:0')
# 	For this mini round, time:  0.3530004024505615  iou  tensor(0.7191, device='cuda:0')
# 	For this mini round, time:  0.3610248565673828  iou  tensor(0.7137, device='cuda:0')
# 	For this mini round, time:  0.363964319229126  iou  tensor(0.7184, device='cuda:0')
# 	For this mini round, time:  0.3769965171813965  iou  tensor(0.7256, device='cuda:0')
# 	For this mini round, time:  0.39100122451782227  iou  tensor(0.7169, device='cuda:0')
# 	For this mini round, time:  0.42599916458129883  iou  tensor(0.7197, device='cuda:0')
# 	For this mini round, time:  0.4000260829925537  iou  tensor(0.7123, device='cuda:0')
# 	For this mini round, time:  0.40897560119628906  iou  tensor(0.7173, device='cuda:0')
# 	For this mini round, time:  0.4200000762939453  iou  tensor(0.7186, device='cuda:0')
# Time on avg:  0.3871988534927368  IOU on avg:  tensor(0.7174, device='cuda:0')
# Round  16
# Training done!  25.515625
# 	For this mini round, time:  0.36797475814819336  iou  tensor(0.7134, device='cuda:0')
# 	For this mini round, time:  0.3600010871887207  iou  tensor(0.7190, device='cuda:0')
# 	For this mini round, time:  0.36702442169189453  iou  tensor(0.7153, device='cuda:0')
# 	For this mini round, time:  0.3679983615875244  iou  tensor(0.7193, device='cuda:0')
# 	For this mini round, time:  0.37800073623657227  iou  tensor(0.7261, device='cuda:0')
# 	For this mini round, time:  0.40799760818481445  iou  tensor(0.7177, device='cuda:0')
# 	For this mini round, time:  0.4070003032684326  iou  tensor(0.7222, device='cuda:0')
# 	For this mini round, time:  0.42299938201904297  iou  tensor(0.7120, device='cuda:0')
# 	For this mini round, time:  0.41100072860717773  iou  tensor(0.7166, device='cuda:0')
# 	For this mini round, time:  0.4309995174407959  iou  tensor(0.7187, device='cuda:0')
# Time on avg:  0.3920996904373169  IOU on avg:  tensor(0.7180, device='cuda:0')
# Round  17
# Training done!  25.765625
# 	For this mini round, time:  0.3670229911804199  iou  tensor(0.6819, device='cuda:0')
# 	For this mini round, time:  0.3690016269683838  iou  tensor(0.6842, device='cuda:0')
# 	For this mini round, time:  0.3740227222442627  iou  tensor(0.6807, device='cuda:0')
# 	For this mini round, time:  0.3680253028869629  iou  tensor(0.6853, device='cuda:0')
# 	For this mini round, time:  0.37798619270324707  iou  tensor(0.6935, device='cuda:0')
# 	For this mini round, time:  0.41900014877319336  iou  tensor(0.6861, device='cuda:0')
# 	For this mini round, time:  0.39999914169311523  iou  tensor(0.6861, device='cuda:0')
# 	For this mini round, time:  0.41299986839294434  iou  tensor(0.6803, device='cuda:0')
# 	For this mini round, time:  0.42000508308410645  iou  tensor(0.6844, device='cuda:0')
# 	For this mini round, time:  0.43602561950683594  iou  tensor(0.6840, device='cuda:0')
# Time on avg:  0.39440886974334716  IOU on avg:  tensor(0.6846, device='cuda:0')
# Round  18
# Training done!  25.65625
# 	For this mini round, time:  0.3579752445220947  iou  tensor(0.7167, device='cuda:0')
# 	For this mini round, time:  0.36902427673339844  iou  tensor(0.7176, device='cuda:0')
# 	For this mini round, time:  0.3740062713623047  iou  tensor(0.7114, device='cuda:0')
# 	For this mini round, time:  0.3569676876068115  iou  tensor(0.7178, device='cuda:0')
# 	For this mini round, time:  0.38699936866760254  iou  tensor(0.7218, device='cuda:0')
# 	For this mini round, time:  0.40999937057495117  iou  tensor(0.7167, device='cuda:0')
# 	For this mini round, time:  0.4020273685455322  iou  tensor(0.7207, device='cuda:0')
# 	For this mini round, time:  0.4200003147125244  iou  tensor(0.7071, device='cuda:0')
# 	For this mini round, time:  0.4200246334075928  iou  tensor(0.7198, device='cuda:0')
# 	For this mini round, time:  0.4379749298095703  iou  tensor(0.7160, device='cuda:0')
# Time on avg:  0.39349994659423826  IOU on avg:  tensor(0.7166, device='cuda:0')
# Round  19
# Training done!  25.625
# 	For this mini round, time:  0.3910255432128906  iou  tensor(0.6984, device='cuda:0')
# 	For this mini round, time:  0.3840010166168213  iou  tensor(0.7007, device='cuda:0')
# 	For this mini round, time:  0.3839986324310303  iou  tensor(0.6994, device='cuda:0')
# 	For this mini round, time:  0.3860001564025879  iou  tensor(0.7011, device='cuda:0')
# 	For this mini round, time:  0.3959999084472656  iou  tensor(0.7094, device='cuda:0')
# 	For this mini round, time:  0.4490020275115967  iou  tensor(0.7030, device='cuda:0')
# 	For this mini round, time:  0.4139997959136963  iou  tensor(0.7012, device='cuda:0')
# 	For this mini round, time:  0.4360239505767822  iou  tensor(0.6946, device='cuda:0')
# 	For this mini round, time:  0.429030179977417  iou  tensor(0.7017, device='cuda:0')
# 	For this mini round, time:  0.4419693946838379  iou  tensor(0.7006, device='cuda:0')
# Time on avg:  0.4111050605773926  IOU on avg:  tensor(0.7010, device='cuda:0')
#
#
# Testing done!
#
# Training time:  25.80625
# Testing time:  0.390576366186142
# Testing acc:  0.7044045209884644
# (array([29.09375 , 25.4375  , 25.65625 , 25.59375 , 25.59375 , 25.546875,
#         25.640625, 25.5     , 25.96875 , 25.515625, 25.484375, 25.84375 ,
#         25.75    , 25.875   , 25.515625, 25.546875, 25.515625, 25.765625,
#         25.65625 , 25.625   ]),
#  array([0.38549976, 0.39409983, 0.38849838, 0.38560681, 0.38930209,
#         0.39100003, 0.39350352, 0.38601563, 0.38580065, 0.38840497,
#         0.39289632, 0.39629714, 0.38499339, 0.38720086, 0.38409553,
#         0.38719885, 0.39209969, 0.39440887, 0.39349995, 0.41110506]),
#  array([0.71000308, 0.68684906, 0.72538358, 0.72356617, 0.71352929,
#         0.68822944, 0.73257381, 0.69967157, 0.67663479, 0.70102805,
#         0.69281399, 0.70023555, 0.72471166, 0.72153276, 0.65365213,
#         0.71742862, 0.71803069, 0.68464679, 0.71655506, 0.70101434]))
