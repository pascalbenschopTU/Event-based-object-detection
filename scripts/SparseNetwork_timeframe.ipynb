# %%
import cv2
import time
import numpy as np
import contextlib
import torch.cuda.amp
import tensorflow as tf
from sklearn.model_selection import train_test_split

import spconv.pytorch as spconv
import torch
import torch.optim as optim
from torch import nn
import torch.nn.functional as F

from util.eventvision import read_dataset, read_annotation
from util.BoundingBoxRegressionUtils import parse_partial_dataset, parse_random_dataset, torch_iou


TIME_FRAME = 10000
# Out:
# Event-based vision module imported

# %%
def getData(filename):
    td = read_dataset(filename)
    
    width = td.width
    height = td.height
    arr = np.array(td.data)
    
    matrix = np.zeros((height, width))
    
    for item in arr:
        if item[3] > TIME_FRAME:
            break
        else:
            x = item[0]
            y = item[1]
            matrix[y][x] = item[3] # item[3] = time stamp
            
    matrix = (matrix / TIME_FRAME)**2       
    matrix = cv2.resize(matrix, (128, 128))
    
    return width, height, matrix

def getAnnotation(filename):
    data = read_annotation(filename)
    minX = min(data[0])
    maxX = max(data[0])
    minY = min(data[1])
    maxY = max(data[1])
    
    return minX, minY, maxX, maxY

# %%
def train(args, model, device, train_loader, optimizer, epoch):
    model.train()
    amp_ctx = contextlib.nullcontext()
    if args.fp16:
        amp_ctx = torch.cuda.amp.autocast()
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        with amp_ctx:
            output = model(data)
            loss = F.mse_loss(output, target)
            loss.backward()
            optimizer.step()

def test(args, model, device, test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    amp_ctx = contextlib.nullcontext()
    if args.fp16:
        amp_ctx = torch.cuda.amp.autocast()

    with torch.no_grad():
        for data, target in test_loader:

            data, target = data.to(device), target.to(device)
            with amp_ctx:

                output = model(data)
            test_loss += F.mse_loss(output, target, reduction='sum').item() # sum up batch loss
            
            correct += torch.sum(torch_iou(output[:, -4:], target[:, -4:]))
            

    test_loss /= len(test_loader.dataset)

    
    return correct / len(test_loader.dataset)

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.net = spconv.SparseSequential(
            spconv.SparseConv2d(1, 16, 5, stride=1, padding=2),
            nn.LeakyReLU(0.1),
            spconv.SparseMaxPool2d(2, 2),
            
            spconv.SparseConv2d(16, 32, 5, stride=1, padding=2),
            nn.LeakyReLU(0.1),
            spconv.SparseMaxPool2d(2, 2),
            
            spconv.SparseConv2d(32, 64, 5, stride=1, padding=2),
            nn.LeakyReLU(0.1),
            spconv.SparseMaxPool2d(2, 2),
            
            spconv.SparseConv2d(64, 128, 5, stride=1, padding=2),
            nn.LeakyReLU(0.1),
            spconv.SparseMaxPool2d(2, 2),
            
            spconv.SparseConv2d(128, 256, 5, stride=1, padding=2),
            nn.LeakyReLU(0.1),
            spconv.SparseMaxPool2d(2, 2),
            
            spconv.ToDense(),
            nn.Flatten(1,-1),
            nn.Dropout(p=0.2),
            nn.Linear(4096, 2048),
            nn.Linear(2048, 1024),
            nn.Linear(1024, 8),
        )

    def forward(self, x: torch.Tensor):
        x = spconv.SparseConvTensor.from_dense(x.reshape(-1, 128, 128, 1))
        y =  self.net(x)
        
        return y

# %%
X_train, X_test, y_train, y_test = parse_partial_dataset(getData, getAnnotation)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

train_loader = torch.utils.data.DataLoader(
    [[X_train[i], y_train[i]] for i in range(len(X_train))], shuffle=False, batch_size=40)
# test_loader = torch.utils.data.DataLoader(
#     [[X_test[i], y_test[i]] for i in range(len(X_test))], shuffle=False, batch_size=40)

args = lambda: None
args.fp16 = True
args.lr = 0.001
args.log_interval = 50

device = torch.device("cuda:0") if torch.cuda.is_available() else torch.device("cpu")
print(device)

def makeTestData():
    testData = []
    
    for i in range(10): 
        X_test, y_test = parse_random_dataset(getData, getAnnotation, True)
        test_loader = torch.utils.data.DataLoader(
            [[X_test[i], y_test[i]] for i in range(len(X_test))], shuffle=False, batch_size=40)
        
        testData.append(test_loader)
        
    return testData

def testTiming(model, testData):
    total_time = 0.0
    total_acc = 0.0
    for i in range(10): 
        test_loader = testData[i]

        testing_time = time.time()

        iou = test(args, model, device, test_loader)

        time_taken = time.time()  - testing_time

        total_time += time_taken
        total_acc += iou

        print("\tFor this mini round, time: ", time_taken, " iou ", iou)

    avg_time = total_time / 10
    avg_acc = total_acc / 10
    
    print("Time on avg: ", avg_time, " IOU on avg: ", avg_acc)
    
    return avg_time, avg_acc

def trainModel():
    model = Net().to(device)
    optimizer = optim.Adam(model.parameters(), lr=args.lr)
    
    train_start_time = time.process_time()

    for epoch in range(0, 40):
        train(args, model, device, train_loader, optimizer, epoch)

    train_time = time.process_time() - train_start_time
    
    print("Training done!  " + str(train_time))
    
    return train_time, model

def getResults():
    testData = makeTestData()
    
    train_timing_results = np.empty(20)
    test_timing_results = np.empty(20)
    test_acc_results = np.empty(20)

    for i in range(20):
        print("Round ", i)

        train_time, model = trainModel()
        train_timing_results[i] = train_time
        
        test_time, test_acc = testTiming(model, testData)
        test_timing_results[i] = test_time
        test_acc_results[i] = test_acc

    print("\n\nTesting done!\n")

    print("Training time: ", np.mean(train_timing_results))
    print("Testing time: ", np.mean(test_timing_results))
    print("Testing acc: ", np.mean(test_acc_results))
    
    return train_timing_results, test_timing_results, test_acc_results

getResults()
# Out:
# cuda:0
# Round  0
# Training done!  47.078125
# 	For this mini round, time:  0.5619997978210449  iou  tensor(0.7546, device='cuda:0')
# 	For this mini round, time:  0.5510001182556152  iou  tensor(0.7564, device='cuda:0')
# 	For this mini round, time:  0.5519990921020508  iou  tensor(0.7521, device='cuda:0')
# 	For this mini round, time:  0.5639991760253906  iou  tensor(0.7588, device='cuda:0')
# 	For this mini round, time:  0.5460343360900879  iou  tensor(0.7632, device='cuda:0')
# 	For this mini round, time:  0.5470004081726074  iou  tensor(0.7519, device='cuda:0')
# 	For this mini round, time:  0.5509998798370361  iou  tensor(0.7496, device='cuda:0')
# 	For this mini round, time:  0.5570006370544434  iou  tensor(0.7467, device='cuda:0')
# 	For this mini round, time:  0.5499992370605469  iou  tensor(0.7525, device='cuda:0')
# 	For this mini round, time:  0.5529990196228027  iou  tensor(0.7565, device='cuda:0')
# Time on avg:  0.5533031702041626  IOU on avg:  tensor(0.7542, device='cuda:0')
# Round  1
# Training done!  39.78125
# 	For this mini round, time:  0.5590004920959473  iou  tensor(0.7451, device='cuda:0')
# 	For this mini round, time:  0.5539999008178711  iou  tensor(0.7475, device='cuda:0')
# 	For this mini round, time:  0.5660006999969482  iou  tensor(0.7444, device='cuda:0')
# 	For this mini round, time:  0.5460293292999268  iou  tensor(0.7488, device='cuda:0')
# 	For this mini round, time:  0.5510005950927734  iou  tensor(0.7486, device='cuda:0')
# 	For this mini round, time:  0.5499687194824219  iou  tensor(0.7430, device='cuda:0')
# 	For this mini round, time:  0.5500001907348633  iou  tensor(0.7435, device='cuda:0')
# 	For this mini round, time:  0.5449991226196289  iou  tensor(0.7369, device='cuda:0')
# 	For this mini round, time:  0.553001880645752  iou  tensor(0.7410, device='cuda:0')
# 	For this mini round, time:  0.545029878616333  iou  tensor(0.7431, device='cuda:0')
# Time on avg:  0.5519030809402465  IOU on avg:  tensor(0.7442, device='cuda:0')
# Round  2
# Training done!  39.578125
# 	For this mini round, time:  0.5550341606140137  iou  tensor(0.7371, device='cuda:0')
# 	For this mini round, time:  0.5470414161682129  iou  tensor(0.7367, device='cuda:0')
# 	For this mini round, time:  0.5480010509490967  iou  tensor(0.7401, device='cuda:0')
# 	For this mini round, time:  0.5510284900665283  iou  tensor(0.7432, device='cuda:0')
# 	For this mini round, time:  0.547027587890625  iou  tensor(0.7423, device='cuda:0')
# 	For this mini round, time:  0.5459680557250977  iou  tensor(0.7343, device='cuda:0')
# 	For this mini round, time:  0.5570003986358643  iou  tensor(0.7359, device='cuda:0')
# 	For this mini round, time:  0.549004077911377  iou  tensor(0.7303, device='cuda:0')
# 	For this mini round, time:  0.545996904373169  iou  tensor(0.7372, device='cuda:0')
# 	For this mini round, time:  0.5460007190704346  iou  tensor(0.7359, device='cuda:0')
# Time on avg:  0.5492102861404419  IOU on avg:  tensor(0.7373, device='cuda:0')
# Round  3
# Training done!  39.640625
# 	For this mini round, time:  0.568000316619873  iou  tensor(0.7883, device='cuda:0')
# 	For this mini round, time:  0.5410299301147461  iou  tensor(0.7890, device='cuda:0')
# 	For this mini round, time:  0.5469999313354492  iou  tensor(0.7883, device='cuda:0')
# 	For this mini round, time:  0.5460309982299805  iou  tensor(0.7957, device='cuda:0')
# 	For this mini round, time:  0.5530297756195068  iou  tensor(0.7932, device='cuda:0')
# 	For this mini round, time:  0.548029899597168  iou  tensor(0.7882, device='cuda:0')
# 	For this mini round, time:  0.5459811687469482  iou  tensor(0.7892, device='cuda:0')
# 	For this mini round, time:  0.544029951095581  iou  tensor(0.7847, device='cuda:0')
# 	For this mini round, time:  0.551999568939209  iou  tensor(0.7851, device='cuda:0')
# 	For this mini round, time:  0.5510318279266357  iou  tensor(0.7927, device='cuda:0')
# Time on avg:  0.5496163368225098  IOU on avg:  tensor(0.7894, device='cuda:0')
# Round  4
# Training done!  39.65625
# 	For this mini round, time:  0.5509686470031738  iou  tensor(0.7559, device='cuda:0')
# 	For this mini round, time:  0.5690000057220459  iou  tensor(0.7598, device='cuda:0')
# 	For this mini round, time:  0.554999828338623  iou  tensor(0.7543, device='cuda:0')
# 	For this mini round, time:  0.562030553817749  iou  tensor(0.7600, device='cuda:0')
# 	For this mini round, time:  0.5849719047546387  iou  tensor(0.7628, device='cuda:0')
# 	For this mini round, time:  0.58599853515625  iou  tensor(0.7557, device='cuda:0')
# 	For this mini round, time:  0.5490317344665527  iou  tensor(0.7565, device='cuda:0')
# 	For this mini round, time:  0.5449652671813965  iou  tensor(0.7478, device='cuda:0')
# 	For this mini round, time:  0.5489552021026611  iou  tensor(0.7540, device='cuda:0')
# 	For this mini round, time:  0.554997444152832  iou  tensor(0.7564, device='cuda:0')
# Time on avg:  0.5605919122695923  IOU on avg:  tensor(0.7563, device='cuda:0')
# Round  5
# Training done!  39.671875
# 	For this mini round, time:  0.5600309371948242  iou  tensor(0.7334, device='cuda:0')
# 	For this mini round, time:  0.5490038394927979  iou  tensor(0.7338, device='cuda:0')
# 	For this mini round, time:  0.5519719123840332  iou  tensor(0.7328, device='cuda:0')
# 	For this mini round, time:  0.5639979839324951  iou  tensor(0.7393, device='cuda:0')
# 	For this mini round, time:  0.5519981384277344  iou  tensor(0.7394, device='cuda:0')
# 	For this mini round, time:  0.5740010738372803  iou  tensor(0.7308, device='cuda:0')
# 	For this mini round, time:  0.5519998073577881  iou  tensor(0.7322, device='cuda:0')
# 	For this mini round, time:  0.5379669666290283  iou  tensor(0.7251, device='cuda:0')
# 	For this mini round, time:  0.5439965724945068  iou  tensor(0.7302, device='cuda:0')
# 	For this mini round, time:  0.5460002422332764  iou  tensor(0.7334, device='cuda:0')
# Time on avg:  0.5530967473983764  IOU on avg:  tensor(0.7330, device='cuda:0')
# Round  6
# Training done!  39.390625
# 	For this mini round, time:  0.5610063076019287  iou  tensor(0.7433, device='cuda:0')
# 	For this mini round, time:  0.5559983253479004  iou  tensor(0.7472, device='cuda:0')
# 	For this mini round, time:  0.54396653175354  iou  tensor(0.7440, device='cuda:0')
# 	For this mini round, time:  0.5510241985321045  iou  tensor(0.7490, device='cuda:0')
# 	For this mini round, time:  0.5430002212524414  iou  tensor(0.7510, device='cuda:0')
# 	For this mini round, time:  0.5480265617370605  iou  tensor(0.7472, device='cuda:0')
# 	For this mini round, time:  0.5440261363983154  iou  tensor(0.7433, device='cuda:0')
# 	For this mini round, time:  0.5439987182617188  iou  tensor(0.7389, device='cuda:0')
# 	For this mini round, time:  0.5490272045135498  iou  tensor(0.7426, device='cuda:0')
# 	For this mini round, time:  0.5519976615905762  iou  tensor(0.7491, device='cuda:0')
# Time on avg:  0.5492071866989136  IOU on avg:  tensor(0.7456, device='cuda:0')
# Round  7
# Training done!  41.0
# 	For this mini round, time:  0.5660288333892822  iou  tensor(0.7509, device='cuda:0')
# 	For this mini round, time:  0.5590322017669678  iou  tensor(0.7526, device='cuda:0')
# 	For this mini round, time:  0.5580003261566162  iou  tensor(0.7491, device='cuda:0')
# 	For this mini round, time:  0.5659999847412109  iou  tensor(0.7569, device='cuda:0')
# 	For this mini round, time:  0.5570392608642578  iou  tensor(0.7551, device='cuda:0')
# 	For this mini round, time:  0.5590016841888428  iou  tensor(0.7476, device='cuda:0')
# 	For this mini round, time:  0.5600302219390869  iou  tensor(0.7490, device='cuda:0')
# 	For this mini round, time:  0.563997745513916  iou  tensor(0.7436, device='cuda:0')
# 	For this mini round, time:  0.5500311851501465  iou  tensor(0.7456, device='cuda:0')
# 	For this mini round, time:  0.5579986572265625  iou  tensor(0.7470, device='cuda:0')
# Time on avg:  0.559716010093689  IOU on avg:  tensor(0.7497, device='cuda:0')
# Round  8
# Training done!  39.65625
# 	For this mini round, time:  0.5520310401916504  iou  tensor(0.7626, device='cuda:0')
# 	For this mini round, time:  0.5439987182617188  iou  tensor(0.7663, device='cuda:0')
# 	For this mini round, time:  0.5460371971130371  iou  tensor(0.7630, device='cuda:0')
# 	For this mini round, time:  0.546999454498291  iou  tensor(0.7693, device='cuda:0')
# 	For this mini round, time:  0.5520308017730713  iou  tensor(0.7656, device='cuda:0')
# 	For this mini round, time:  0.5450305938720703  iou  tensor(0.7638, device='cuda:0')
# 	For this mini round, time:  0.5510292053222656  iou  tensor(0.7600, device='cuda:0')
# 	For this mini round, time:  0.543032169342041  iou  tensor(0.7551, device='cuda:0')
# 	For this mini round, time:  0.5529994964599609  iou  tensor(0.7625, device='cuda:0')
# 	For this mini round, time:  0.5560305118560791  iou  tensor(0.7650, device='cuda:0')
# Time on avg:  0.5489219188690185  IOU on avg:  tensor(0.7633, device='cuda:0')
# Round  9
# Training done!  39.515625
# 	For this mini round, time:  0.5499997138977051  iou  tensor(0.7475, device='cuda:0')
# 	For this mini round, time:  0.5429883003234863  iou  tensor(0.7531, device='cuda:0')
# 	For this mini round, time:  0.5500304698944092  iou  tensor(0.7415, device='cuda:0')
# 	For this mini round, time:  0.5360019207000732  iou  tensor(0.7532, device='cuda:0')
# 	For this mini round, time:  0.544999361038208  iou  tensor(0.7562, device='cuda:0')
# 	For this mini round, time:  0.5510125160217285  iou  tensor(0.7477, device='cuda:0')
# 	For this mini round, time:  0.5519869327545166  iou  tensor(0.7446, device='cuda:0')
# 	For this mini round, time:  0.5499708652496338  iou  tensor(0.7406, device='cuda:0')
# 	For this mini round, time:  0.5460019111633301  iou  tensor(0.7478, device='cuda:0')
# 	For this mini round, time:  0.549968957901001  iou  tensor(0.7531, device='cuda:0')
# Time on avg:  0.5472960948944092  IOU on avg:  tensor(0.7485, device='cuda:0')
# Round  10
# Training done!  39.5
# 	For this mini round, time:  0.5629677772521973  iou  tensor(0.7498, device='cuda:0')
# 	For this mini round, time:  0.5460002422332764  iou  tensor(0.7531, device='cuda:0')
# 	For this mini round, time:  0.5460293292999268  iou  tensor(0.7482, device='cuda:0')
# 	For this mini round, time:  0.5419681072235107  iou  tensor(0.7529, device='cuda:0')
# 	For this mini round, time:  0.5540311336517334  iou  tensor(0.7504, device='cuda:0')
# 	For this mini round, time:  0.5499670505523682  iou  tensor(0.7528, device='cuda:0')
# 	For this mini round, time:  0.5519685745239258  iou  tensor(0.7473, device='cuda:0')
# 	For this mini round, time:  0.5480310916900635  iou  tensor(0.7473, device='cuda:0')
# 	For this mini round, time:  0.5459902286529541  iou  tensor(0.7444, device='cuda:0')
# 	For this mini round, time:  0.5490283966064453  iou  tensor(0.7496, device='cuda:0')
# Time on avg:  0.5495981931686401  IOU on avg:  tensor(0.7496, device='cuda:0')
# Round  11
# Training done!  39.546875
# 	For this mini round, time:  0.5530014038085938  iou  tensor(0.7477, device='cuda:0')
# 	For this mini round, time:  0.5490002632141113  iou  tensor(0.7534, device='cuda:0')
# 	For this mini round, time:  0.5520305633544922  iou  tensor(0.7490, device='cuda:0')
# 	For this mini round, time:  0.5449984073638916  iou  tensor(0.7545, device='cuda:0')
# 	For this mini round, time:  0.5529663562774658  iou  tensor(0.7523, device='cuda:0')
# 	For this mini round, time:  0.5509912967681885  iou  tensor(0.7521, device='cuda:0')
# 	For this mini round, time:  0.5530002117156982  iou  tensor(0.7472, device='cuda:0')
# 	For this mini round, time:  0.5380401611328125  iou  tensor(0.7441, device='cuda:0')
# 	For this mini round, time:  0.5440070629119873  iou  tensor(0.7476, device='cuda:0')
# 	For this mini round, time:  0.5469686985015869  iou  tensor(0.7491, device='cuda:0')
# Time on avg:  0.5485004425048828  IOU on avg:  tensor(0.7497, device='cuda:0')
# Round  12
# Training done!  39.5625
# 	For this mini round, time:  0.5510306358337402  iou  tensor(0.7567, device='cuda:0')
# 	For this mini round, time:  0.5390298366546631  iou  tensor(0.7597, device='cuda:0')
# 	For this mini round, time:  0.5460264682769775  iou  tensor(0.7571, device='cuda:0')
# 	For this mini round, time:  0.5519900321960449  iou  tensor(0.7649, device='cuda:0')
# 	For this mini round, time:  0.5449995994567871  iou  tensor(0.7634, device='cuda:0')
# 	For this mini round, time:  0.5500001907348633  iou  tensor(0.7610, device='cuda:0')
# 	For this mini round, time:  0.5570006370544434  iou  tensor(0.7592, device='cuda:0')
# 	For this mini round, time:  0.5539999008178711  iou  tensor(0.7508, device='cuda:0')
# 	For this mini round, time:  0.551034688949585  iou  tensor(0.7567, device='cuda:0')
# 	For this mini round, time:  0.5429656505584717  iou  tensor(0.7590, device='cuda:0')
# Time on avg:  0.5488077640533447  IOU on avg:  tensor(0.7589, device='cuda:0')
# Round  13
# Training done!  39.609375
# 	For this mini round, time:  0.5539891719818115  iou  tensor(0.6760, device='cuda:0')
# 	For this mini round, time:  0.5499982833862305  iou  tensor(0.6755, device='cuda:0')
# 	For this mini round, time:  0.5460336208343506  iou  tensor(0.6773, device='cuda:0')
# 	For this mini round, time:  0.5439982414245605  iou  tensor(0.6868, device='cuda:0')
# 	For this mini round, time:  0.5440011024475098  iou  tensor(0.6815, device='cuda:0')
# 	For this mini round, time:  0.5529646873474121  iou  tensor(0.6752, device='cuda:0')
# 	For this mini round, time:  0.549999475479126  iou  tensor(0.6782, device='cuda:0')
# 	For this mini round, time:  0.5469672679901123  iou  tensor(0.6702, device='cuda:0')
# 	For this mini round, time:  0.5410301685333252  iou  tensor(0.6731, device='cuda:0')
# 	For this mini round, time:  0.5590031147003174  iou  tensor(0.6812, device='cuda:0')
# Time on avg:  0.5487985134124755  IOU on avg:  tensor(0.6775, device='cuda:0')
# Round  14
# Training done!  39.421875
# 	For this mini round, time:  0.556999921798706  iou  tensor(0.7394, device='cuda:0')
# 	For this mini round, time:  0.5450315475463867  iou  tensor(0.7427, device='cuda:0')
# 	For this mini round, time:  0.551999568939209  iou  tensor(0.7415, device='cuda:0')
# 	For this mini round, time:  0.5560295581817627  iou  tensor(0.7451, device='cuda:0')
# 	For this mini round, time:  0.5469942092895508  iou  tensor(0.7449, device='cuda:0')
# 	For this mini round, time:  0.5490312576293945  iou  tensor(0.7384, device='cuda:0')
# 	For this mini round, time:  0.5689675807952881  iou  tensor(0.7389, device='cuda:0')
# 	For this mini round, time:  0.5450000762939453  iou  tensor(0.7335, device='cuda:0')
# 	For this mini round, time:  0.5430006980895996  iou  tensor(0.7353, device='cuda:0')
# 	For this mini round, time:  0.5430302619934082  iou  tensor(0.7402, device='cuda:0')
# Time on avg:  0.550608468055725  IOU on avg:  tensor(0.7400, device='cuda:0')
# Round  15
# Training done!  39.53125
# 	For this mini round, time:  0.5540332794189453  iou  tensor(0.7138, device='cuda:0')
# 	For this mini round, time:  0.5480310916900635  iou  tensor(0.7184, device='cuda:0')
# 	For this mini round, time:  0.5460312366485596  iou  tensor(0.7102, device='cuda:0')
# 	For this mini round, time:  0.5490005016326904  iou  tensor(0.7191, device='cuda:0')
# 	For this mini round, time:  0.5530338287353516  iou  tensor(0.7223, device='cuda:0')
# 	For this mini round, time:  0.5570299625396729  iou  tensor(0.7141, device='cuda:0')
# 	For this mini round, time:  0.546999454498291  iou  tensor(0.7094, device='cuda:0')
# 	For this mini round, time:  0.5490326881408691  iou  tensor(0.7062, device='cuda:0')
# 	For this mini round, time:  0.5549986362457275  iou  tensor(0.7123, device='cuda:0')
# 	For this mini round, time:  0.5490295886993408  iou  tensor(0.7176, device='cuda:0')
# Time on avg:  0.5507220268249512  IOU on avg:  tensor(0.7143, device='cuda:0')
# Round  16
# Training done!  39.28125
# 	For this mini round, time:  0.5569748878479004  iou  tensor(0.7601, device='cuda:0')
# 	For this mini round, time:  0.5459988117218018  iou  tensor(0.7629, device='cuda:0')
# 	For this mini round, time:  0.5450246334075928  iou  tensor(0.7586, device='cuda:0')
# 	For this mini round, time:  0.5459997653961182  iou  tensor(0.7669, device='cuda:0')
# 	For this mini round, time:  0.540999174118042  iou  tensor(0.7670, device='cuda:0')
# 	For this mini round, time:  0.5460333824157715  iou  tensor(0.7597, device='cuda:0')
# 	For this mini round, time:  0.5529994964599609  iou  tensor(0.7592, device='cuda:0')
# 	For this mini round, time:  0.5499982833862305  iou  tensor(0.7521, device='cuda:0')
# 	For this mini round, time:  0.5350334644317627  iou  tensor(0.7590, device='cuda:0')
# 	For this mini round, time:  0.5449976921081543  iou  tensor(0.7632, device='cuda:0')
# Time on avg:  0.5464059591293335  IOU on avg:  tensor(0.7609, device='cuda:0')
# Round  17
# Training done!  39.4375
# 	For this mini round, time:  0.5529682636260986  iou  tensor(0.7444, device='cuda:0')
# 	For this mini round, time:  0.5360002517700195  iou  tensor(0.7453, device='cuda:0')
# 	For this mini round, time:  0.5499975681304932  iou  tensor(0.7430, device='cuda:0')
# 	For this mini round, time:  0.548959493637085  iou  tensor(0.7500, device='cuda:0')
# 	For this mini round, time:  0.5569884777069092  iou  tensor(0.7500, device='cuda:0')
# 	For this mini round, time:  0.5520036220550537  iou  tensor(0.7424, device='cuda:0')
# 	For this mini round, time:  0.5509719848632812  iou  tensor(0.7426, device='cuda:0')
# 	For this mini round, time:  0.5460171699523926  iou  tensor(0.7355, device='cuda:0')
# 	For this mini round, time:  0.5469987392425537  iou  tensor(0.7388, device='cuda:0')
# 	For this mini round, time:  0.5710000991821289  iou  tensor(0.7443, device='cuda:0')
# Time on avg:  0.5511905670166015  IOU on avg:  tensor(0.7436, device='cuda:0')
# Round  18
# Training done!  39.578125
# 	For this mini round, time:  0.5530030727386475  iou  tensor(0.7723, device='cuda:0')
# 	For this mini round, time:  0.5489652156829834  iou  tensor(0.7726, device='cuda:0')
# 	For this mini round, time:  0.5499975681304932  iou  tensor(0.7698, device='cuda:0')
# 	For this mini round, time:  0.5479695796966553  iou  tensor(0.7784, device='cuda:0')
# 	For this mini round, time:  0.5500094890594482  iou  tensor(0.7715, device='cuda:0')
# 	For this mini round, time:  0.5419692993164062  iou  tensor(0.7698, device='cuda:0')
# 	For this mini round, time:  0.5560302734375  iou  tensor(0.7708, device='cuda:0')
# 	For this mini round, time:  0.5470290184020996  iou  tensor(0.7656, device='cuda:0')
# 	For this mini round, time:  0.5439996719360352  iou  tensor(0.7675, device='cuda:0')
# 	For this mini round, time:  0.5459692478179932  iou  tensor(0.7742, device='cuda:0')
# Time on avg:  0.5484942436218262  IOU on avg:  tensor(0.7712, device='cuda:0')
# Round  19
# Training done!  39.46875
# 	For this mini round, time:  0.5520398616790771  iou  tensor(0.7480, device='cuda:0')
# 	For this mini round, time:  0.5450000762939453  iou  tensor(0.7527, device='cuda:0')
# 	For this mini round, time:  0.5469999313354492  iou  tensor(0.7470, device='cuda:0')
# 	For this mini round, time:  0.5460319519042969  iou  tensor(0.7560, device='cuda:0')
# 	For this mini round, time:  0.5540306568145752  iou  tensor(0.7529, device='cuda:0')
# 	For this mini round, time:  0.5479979515075684  iou  tensor(0.7504, device='cuda:0')
# 	For this mini round, time:  0.5520284175872803  iou  tensor(0.7489, device='cuda:0')
# 	For this mini round, time:  0.557002067565918  iou  tensor(0.7431, device='cuda:0')
# 	For this mini round, time:  0.5460021495819092  iou  tensor(0.7471, device='cuda:0')
# 	For this mini round, time:  0.5520339012145996  iou  tensor(0.7514, device='cuda:0')
# Time on avg:  0.5499166965484619  IOU on avg:  tensor(0.7498, device='cuda:0')
#
#
# Testing done!
#
# Training time:  39.9953125
# Testing time:  0.55079528093338
# Testing acc:  0.7468577027320862
# (array([47.078125, 39.78125 , 39.578125, 39.640625, 39.65625 , 39.671875,
#         39.390625, 41.      , 39.65625 , 39.515625, 39.5     , 39.546875,
#         39.5625  , 39.609375, 39.421875, 39.53125 , 39.28125 , 39.4375  ,
#         39.578125, 39.46875 ]),
#  array([0.55330317, 0.55190308, 0.54921029, 0.54961634, 0.56059191,
#         0.55309675, 0.54920719, 0.55971601, 0.54892192, 0.54729609,
#         0.54959819, 0.54850044, 0.54880776, 0.54879851, 0.55060847,
#         0.55072203, 0.54640596, 0.55119057, 0.54849424, 0.5499167 ]),
#  array([0.75424844, 0.74419296, 0.7373051 , 0.78942674, 0.75631338,
#         0.73303252, 0.74555093, 0.74974346, 0.7633301 , 0.7485323 ,
#         0.74957383, 0.74972051, 0.75886577, 0.67749876, 0.73999375,
#         0.71433794, 0.76086396, 0.74362916, 0.77124232, 0.7497521 ]))
