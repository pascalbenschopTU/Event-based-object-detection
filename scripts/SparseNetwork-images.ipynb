# %%
import cv2
import time
import numpy as np
import contextlib
import torch.cuda.amp
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from sklearn.model_selection import train_test_split
import scipy.io

import spconv.pytorch as spconv
import torch
import torch.optim as optim
from torch import nn
import torch.nn.functional as F

from util.BoundingBoxRegressionUtils import parse_random_dataset, parse_partial_dataset, torch_iou
# Out:
# Event-based vision module imported

# %%
def getData(filename):
    img = load_img(filename)
    
    data = img_to_array(img)
    arr = np.array(data)
    width = arr.shape[1]
    height = arr.shape[0]
    
    arr = cv2.resize(arr, (128,128)) / 256
    
    return width, height, arr

def getAnnotation(filename):
    mat = scipy.io.loadmat(filename)
    data = np.array(mat["box_coord"][0])
    minX = data[2]
    maxX = data[3]
    minY = data[0]
    maxY = data[1]
    
    return minX, minY, maxX, maxY

# %%
def train(args, model, device, train_loader, optimizer, epoch):
    model.train()
    amp_ctx = contextlib.nullcontext()
    if args.fp16:
        amp_ctx = torch.cuda.amp.autocast()
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        with amp_ctx:
            output = model(data)
            loss = F.mse_loss(output, target)
            loss.backward()
            optimizer.step()

def test(args, model, device, test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    amp_ctx = contextlib.nullcontext()
    if args.fp16:
        amp_ctx = torch.cuda.amp.autocast()

    with torch.no_grad():
        for data, target in test_loader:

            data, target = data.to(device), target.to(device)
            with amp_ctx:

                output = model(data)
            test_loss += F.mse_loss(output, target, reduction='sum').item() # sum up batch loss
            
            correct += torch.sum(torch_iou(output[:, -4:], target[:, -4:]))
            

    test_loss /= len(test_loader.dataset)

    
    return correct / len(test_loader.dataset)

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.net = spconv.SparseSequential(
            spconv.SparseConv2d(3, 16, 5, stride=1, padding=2),
            nn.LeakyReLU(0.1),
            spconv.SparseMaxPool2d(2, 2),
            
            spconv.SparseConv2d(16, 32, 5, stride=1, padding=2),
            nn.LeakyReLU(0.1),
            spconv.SparseMaxPool2d(2, 2),
            
            spconv.SparseConv2d(32, 64, 5, stride=1, padding=2),
            nn.LeakyReLU(0.1),
            spconv.SparseMaxPool2d(2, 2),
            
            spconv.SparseConv2d(64, 128, 5, stride=1, padding=2),
            nn.LeakyReLU(0.1),
            spconv.SparseMaxPool2d(2, 2),
            
            spconv.SparseConv2d(128, 256, 5, stride=1, padding=2),
            nn.LeakyReLU(0.1),
            spconv.SparseMaxPool2d(2, 2),
            
            spconv.ToDense(),
            nn.Flatten(1,-1),
            nn.Dropout(p=0.2),
            nn.Linear(4096, 2048),
            nn.Linear(2048, 1024),
            nn.Linear(1024, 8),
        )

    def forward(self, x: torch.Tensor):
        x = spconv.SparseConvTensor.from_dense(x.reshape(-1, 128, 128, 3))
        y =  self.net(x)
        
        return y

# %%
X_train, X_test, y_train, y_test = parse_partial_dataset(getData, getAnnotation, False)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

train_loader = torch.utils.data.DataLoader(
    [[X_train[i], y_train[i]] for i in range(len(X_train))], shuffle=False, batch_size=40)
# test_loader = torch.utils.data.DataLoader(
#     [[X_test[i], y_test[i]] for i in range(len(X_test))], shuffle=False, batch_size=40)

args = lambda: None
args.fp16 = True
args.lr = 0.001
args.log_interval = 50

device = torch.device("cuda:0") if torch.cuda.is_available() else torch.device("cpu")
print(device)

def makeTestData():
    testData = []
    
    for i in range(10): 
        X_test, y_test = parse_random_dataset(getData, getAnnotation, False)
        test_loader = torch.utils.data.DataLoader(
            [[X_test[i], y_test[i]] for i in range(len(X_test))], shuffle=False, batch_size=40)
        
        testData.append(test_loader)
        
    return testData

def testTiming(model, testData):
    total_time = 0.0
    total_acc = 0.0
    for i in range(10): 
        test_loader = testData[i]

        testing_time = time.time()

        iou = test(args, model, device, test_loader)

        time_taken = time.time()  - testing_time

        total_time += time_taken
        total_acc += iou

        print("\tFor this mini round, time: ", time_taken, " iou ", iou)

    avg_time = total_time / 10
    avg_acc = total_acc / 10
    
    print("Time on avg: ", avg_time, " IOU on avg: ", avg_acc)
    
    return avg_time, avg_acc

def trainModel():
    model = Net().to(device)
    optimizer = optim.Adam(model.parameters(), lr=args.lr)
    
    train_start_time = time.process_time()

    for epoch in range(0, 40):
        train(args, model, device, train_loader, optimizer, epoch)

    train_time = time.process_time() - train_start_time
    
    print("Training done!  " + str(train_time))
    
    return train_time, model

def getResults():
    testData = makeTestData()
    
    train_timing_results = np.empty(20)
    test_timing_results = np.empty(20)
    test_acc_results = np.empty(20)

    for i in range(20):
        print("Round ", i)

        train_time, model = trainModel()
        train_timing_results[i] = train_time
        
        test_time, test_acc = testTiming(model, testData)
        test_timing_results[i] = test_time
        test_acc_results[i] = test_acc

    print("\n\nTesting done!\n")

    print("Training time: ", np.mean(train_timing_results))
    print("Testing time: ", np.mean(test_timing_results))
    print("Testing acc: ", np.mean(test_acc_results))
    
    return train_timing_results, test_timing_results, test_acc_results

getResults()
# Out:
# cuda:0
# Round  0
# Training done!  439.625
# 	For this mini round, time:  1.1820001602172852  iou  tensor(0.7090, device='cuda:0')
# 	For this mini round, time:  1.1450011730194092  iou  tensor(0.7187, device='cuda:0')
# 	For this mini round, time:  1.1629998683929443  iou  tensor(0.7034, device='cuda:0')
# 	For this mini round, time:  1.218001127243042  iou  tensor(0.7097, device='cuda:0')
# 	For this mini round, time:  1.1969990730285645  iou  tensor(0.7055, device='cuda:0')
# 	For this mini round, time:  1.150998592376709  iou  tensor(0.7141, device='cuda:0')
# 	For this mini round, time:  1.1700000762939453  iou  tensor(0.7049, device='cuda:0')
# 	For this mini round, time:  1.1409990787506104  iou  tensor(0.7180, device='cuda:0')
# 	For this mini round, time:  1.1660058498382568  iou  tensor(0.7162, device='cuda:0')
# 	For this mini round, time:  1.1990010738372803  iou  tensor(0.7021, device='cuda:0')
# Time on avg:  1.1732006072998047  IOU on avg:  tensor(0.7102, device='cuda:0')
# Round  1
# Training done!  423.625
# 	For this mini round, time:  1.1429996490478516  iou  tensor(0.7556, device='cuda:0')
# 	For this mini round, time:  1.1259996891021729  iou  tensor(0.7625, device='cuda:0')
# 	For this mini round, time:  1.1370007991790771  iou  tensor(0.7553, device='cuda:0')
# 	For this mini round, time:  1.119999647140503  iou  tensor(0.7533, device='cuda:0')
# 	For this mini round, time:  1.1319994926452637  iou  tensor(0.7532, device='cuda:0')
# 	For this mini round, time:  1.1220014095306396  iou  tensor(0.7601, device='cuda:0')
# 	For this mini round, time:  1.124999761581421  iou  tensor(0.7539, device='cuda:0')
# 	For this mini round, time:  1.1249992847442627  iou  tensor(0.7596, device='cuda:0')
# 	For this mini round, time:  1.1239995956420898  iou  tensor(0.7633, device='cuda:0')
# 	For this mini round, time:  1.1330008506774902  iou  tensor(0.7486, device='cuda:0')
# Time on avg:  1.1287000179290771  IOU on avg:  tensor(0.7565, device='cuda:0')
# Round  2
# Training done!  424.109375
# 	For this mini round, time:  1.1380000114440918  iou  tensor(0.7224, device='cuda:0')
# 	For this mini round, time:  1.1380000114440918  iou  tensor(0.7266, device='cuda:0')
# 	For this mini round, time:  1.1260011196136475  iou  tensor(0.7170, device='cuda:0')
# 	For this mini round, time:  1.1240007877349854  iou  tensor(0.7267, device='cuda:0')
# 	For this mini round, time:  1.123999834060669  iou  tensor(0.7144, device='cuda:0')
# 	For this mini round, time:  1.127000331878662  iou  tensor(0.7300, device='cuda:0')
# 	For this mini round, time:  1.1209995746612549  iou  tensor(0.7248, device='cuda:0')
# 	For this mini round, time:  1.1270055770874023  iou  tensor(0.7309, device='cuda:0')
# 	For this mini round, time:  1.1210010051727295  iou  tensor(0.7347, device='cuda:0')
# 	For this mini round, time:  1.1289997100830078  iou  tensor(0.7187, device='cuda:0')
# Time on avg:  1.127500796318054  IOU on avg:  tensor(0.7246, device='cuda:0')
# Round  3
# Training done!  421.921875
# 	For this mini round, time:  1.1440000534057617  iou  tensor(0.7249, device='cuda:0')
# 	For this mini round, time:  1.124999761581421  iou  tensor(0.7309, device='cuda:0')
# 	For this mini round, time:  1.1309998035430908  iou  tensor(0.7157, device='cuda:0')
# 	For this mini round, time:  1.1200056076049805  iou  tensor(0.7219, device='cuda:0')
# 	For this mini round, time:  1.1229994297027588  iou  tensor(0.7244, device='cuda:0')
# 	For this mini round, time:  1.1750006675720215  iou  tensor(0.7280, device='cuda:0')
# 	For this mini round, time:  1.1819992065429688  iou  tensor(0.7206, device='cuda:0')
# 	For this mini round, time:  1.1209971904754639  iou  tensor(0.7302, device='cuda:0')
# 	For this mini round, time:  1.1240010261535645  iou  tensor(0.7305, device='cuda:0')
# 	For this mini round, time:  1.11799955368042  iou  tensor(0.7157, device='cuda:0')
# Time on avg:  1.136300230026245  IOU on avg:  tensor(0.7243, device='cuda:0')
# Round  4
# Training done!  418.125
# 	For this mini round, time:  1.1420016288757324  iou  tensor(0.6916, device='cuda:0')
# 	For this mini round, time:  1.1899993419647217  iou  tensor(0.7064, device='cuda:0')
# 	For this mini round, time:  1.1220002174377441  iou  tensor(0.6852, device='cuda:0')
# 	For this mini round, time:  1.3200023174285889  iou  tensor(0.6953, device='cuda:0')
# 	For this mini round, time:  1.1849982738494873  iou  tensor(0.6897, device='cuda:0')
# 	For this mini round, time:  1.166001319885254  iou  tensor(0.6986, device='cuda:0')
# 	For this mini round, time:  1.1369991302490234  iou  tensor(0.6903, device='cuda:0')
# 	For this mini round, time:  1.1580009460449219  iou  tensor(0.7016, device='cuda:0')
# 	For this mini round, time:  1.1300005912780762  iou  tensor(0.7007, device='cuda:0')
# 	For this mini round, time:  1.13200044631958  iou  tensor(0.6811, device='cuda:0')
# Time on avg:  1.168200421333313  IOU on avg:  tensor(0.6940, device='cuda:0')
# Round  5
# Training done!  417.640625
# 	For this mini round, time:  1.4690001010894775  iou  tensor(0.7406, device='cuda:0')
# 	For this mini round, time:  1.1849987506866455  iou  tensor(0.7516, device='cuda:0')
# 	For this mini round, time:  1.1560008525848389  iou  tensor(0.7407, device='cuda:0')
# 	For this mini round, time:  1.1390001773834229  iou  tensor(0.7410, device='cuda:0')
# 	For this mini round, time:  1.1730010509490967  iou  tensor(0.7368, device='cuda:0')
# 	For this mini round, time:  1.149000644683838  iou  tensor(0.7513, device='cuda:0')
# 	For this mini round, time:  1.183000087738037  iou  tensor(0.7392, device='cuda:0')
# 	For this mini round, time:  1.1619999408721924  iou  tensor(0.7434, device='cuda:0')
# 	For this mini round, time:  1.147001028060913  iou  tensor(0.7457, device='cuda:0')
# 	For this mini round, time:  1.141000747680664  iou  tensor(0.7356, device='cuda:0')
# Time on avg:  1.1904003381729127  IOU on avg:  tensor(0.7426, device='cuda:0')
# Round  6
# Training done!  416.234375
# 	For this mini round, time:  1.140000820159912  iou  tensor(0.7504, device='cuda:0')
# 	For this mini round, time:  1.1299974918365479  iou  tensor(0.7564, device='cuda:0')
# 	For this mini round, time:  1.1329991817474365  iou  tensor(0.7454, device='cuda:0')
# 	For this mini round, time:  1.119001865386963  iou  tensor(0.7466, device='cuda:0')
# 	For this mini round, time:  1.125000238418579  iou  tensor(0.7443, device='cuda:0')
# 	For this mini round, time:  1.122999668121338  iou  tensor(0.7546, device='cuda:0')
# 	For this mini round, time:  1.127000331878662  iou  tensor(0.7491, device='cuda:0')
# 	For this mini round, time:  1.1199991703033447  iou  tensor(0.7489, device='cuda:0')
# 	For this mini round, time:  1.124999761581421  iou  tensor(0.7574, device='cuda:0')
# 	For this mini round, time:  1.119001865386963  iou  tensor(0.7433, device='cuda:0')
# Time on avg:  1.1261000394821168  IOU on avg:  tensor(0.7496, device='cuda:0')
# Round  7
# Training done!  415.34375
# 	For this mini round, time:  1.1499996185302734  iou  tensor(0.7620, device='cuda:0')
# 	For this mini round, time:  1.1229991912841797  iou  tensor(0.7703, device='cuda:0')
# 	For this mini round, time:  1.1379995346069336  iou  tensor(0.7633, device='cuda:0')
# 	For this mini round, time:  1.1340012550354004  iou  tensor(0.7602, device='cuda:0')
# 	For this mini round, time:  1.1329994201660156  iou  tensor(0.7572, device='cuda:0')
# 	For this mini round, time:  1.133000135421753  iou  tensor(0.7673, device='cuda:0')
# 	For this mini round, time:  1.1230008602142334  iou  tensor(0.7611, device='cuda:0')
# 	For this mini round, time:  1.1290013790130615  iou  tensor(0.7612, device='cuda:0')
# 	For this mini round, time:  1.127000331878662  iou  tensor(0.7675, device='cuda:0')
# 	For this mini round, time:  1.1299991607666016  iou  tensor(0.7563, device='cuda:0')
# Time on avg:  1.1320000886917114  IOU on avg:  tensor(0.7626, device='cuda:0')
# Round  8
# Training done!  425.625
# 	For this mini round, time:  1.1359999179840088  iou  tensor(0.7759, device='cuda:0')
# 	For this mini round, time:  1.1290006637573242  iou  tensor(0.7845, device='cuda:0')
# 	For this mini round, time:  1.1239995956420898  iou  tensor(0.7722, device='cuda:0')
# 	For this mini round, time:  1.1269986629486084  iou  tensor(0.7767, device='cuda:0')
# 	For this mini round, time:  1.1290016174316406  iou  tensor(0.7718, device='cuda:0')
# 	For this mini round, time:  1.1369988918304443  iou  tensor(0.7825, device='cuda:0')
# 	For this mini round, time:  1.1330010890960693  iou  tensor(0.7749, device='cuda:0')
# 	For this mini round, time:  1.13100004196167  iou  tensor(0.7811, device='cuda:0')
# 	For this mini round, time:  1.1359984874725342  iou  tensor(0.7791, device='cuda:0')
# 	For this mini round, time:  1.1459991931915283  iou  tensor(0.7684, device='cuda:0')
# Time on avg:  1.1327998161315918  IOU on avg:  tensor(0.7767, device='cuda:0')
# Round  9
# Training done!  416.9375
# 	For this mini round, time:  1.1389999389648438  iou  tensor(0.6844, device='cuda:0')
# 	For this mini round, time:  1.1189994812011719  iou  tensor(0.6970, device='cuda:0')
# 	For this mini round, time:  1.1219995021820068  iou  tensor(0.6776, device='cuda:0')
# 	For this mini round, time:  1.115999460220337  iou  tensor(0.6862, device='cuda:0')
# 	For this mini round, time:  1.125000238418579  iou  tensor(0.6814, device='cuda:0')
# 	For this mini round, time:  1.1180000305175781  iou  tensor(0.6886, device='cuda:0')
# 	For this mini round, time:  1.1250009536743164  iou  tensor(0.6811, device='cuda:0')
# 	For this mini round, time:  1.117999792098999  iou  tensor(0.6913, device='cuda:0')
# 	For this mini round, time:  1.1209990978240967  iou  tensor(0.6922, device='cuda:0')
# 	For this mini round, time:  1.1190004348754883  iou  tensor(0.6742, device='cuda:0')
# Time on avg:  1.1221998929977417  IOU on avg:  tensor(0.6854, device='cuda:0')
# Round  10
# Training done!  422.171875
# 	For this mini round, time:  1.1319987773895264  iou  tensor(0.7779, device='cuda:0')
# 	For this mini round, time:  1.1329994201660156  iou  tensor(0.7816, device='cuda:0')
# 	For this mini round, time:  1.1210007667541504  iou  tensor(0.7776, device='cuda:0')
# 	For this mini round, time:  1.122999668121338  iou  tensor(0.7764, device='cuda:0')
# 	For this mini round, time:  1.116999864578247  iou  tensor(0.7679, device='cuda:0')
# 	For this mini round, time:  1.1250004768371582  iou  tensor(0.7825, device='cuda:0')
# 	For this mini round, time:  1.1179990768432617  iou  tensor(0.7738, device='cuda:0')
# 	For this mini round, time:  1.1220011711120605  iou  tensor(0.7769, device='cuda:0')
# 	For this mini round, time:  1.1160004138946533  iou  tensor(0.7839, device='cuda:0')
# 	For this mini round, time:  1.1219992637634277  iou  tensor(0.7745, device='cuda:0')
# Time on avg:  1.1228998899459839  IOU on avg:  tensor(0.7773, device='cuda:0')
# Round  11
# Training done!  422.1875
# 	For this mini round, time:  1.1310007572174072  iou  tensor(0.7412, device='cuda:0')
# 	For this mini round, time:  1.1189990043640137  iou  tensor(0.7530, device='cuda:0')
# 	For this mini round, time:  1.119001865386963  iou  tensor(0.7396, device='cuda:0')
# 	For this mini round, time:  1.117999792098999  iou  tensor(0.7440, device='cuda:0')
# 	For this mini round, time:  1.117002010345459  iou  tensor(0.7342, device='cuda:0')
# 	For this mini round, time:  1.1169989109039307  iou  tensor(0.7525, device='cuda:0')
# 	For this mini round, time:  1.1240007877349854  iou  tensor(0.7425, device='cuda:0')
# 	For this mini round, time:  1.122999906539917  iou  tensor(0.7473, device='cuda:0')
# 	For this mini round, time:  1.1239984035491943  iou  tensor(0.7464, device='cuda:0')
# 	For this mini round, time:  1.1150004863739014  iou  tensor(0.7360, device='cuda:0')
# Time on avg:  1.120700192451477  IOU on avg:  tensor(0.7437, device='cuda:0')
# Round  12
# Training done!  423.46875
# 	For this mini round, time:  1.1370007991790771  iou  tensor(0.6745, device='cuda:0')
# 	For this mini round, time:  1.1170008182525635  iou  tensor(0.6862, device='cuda:0')
# 	For this mini round, time:  1.124000072479248  iou  tensor(0.6680, device='cuda:0')
# 	For this mini round, time:  1.1159999370574951  iou  tensor(0.6760, device='cuda:0')
# 	For this mini round, time:  1.121000051498413  iou  tensor(0.6718, device='cuda:0')
# 	For this mini round, time:  1.1150004863739014  iou  tensor(0.6781, device='cuda:0')
# 	For this mini round, time:  1.1190016269683838  iou  tensor(0.6713, device='cuda:0')
# 	For this mini round, time:  1.1150012016296387  iou  tensor(0.6804, device='cuda:0')
# 	For this mini round, time:  1.1210005283355713  iou  tensor(0.6821, device='cuda:0')
# 	For this mini round, time:  1.1160016059875488  iou  tensor(0.6646, device='cuda:0')
# Time on avg:  1.1201007127761842  IOU on avg:  tensor(0.6753, device='cuda:0')
# Round  13
# Training done!  423.078125
# 	For this mini round, time:  1.1270010471343994  iou  tensor(0.6804, device='cuda:0')
# 	For this mini round, time:  1.1190009117126465  iou  tensor(0.6935, device='cuda:0')
# 	For this mini round, time:  1.1099989414215088  iou  tensor(0.6739, device='cuda:0')
# 	For this mini round, time:  1.1180002689361572  iou  tensor(0.6828, device='cuda:0')
# 	For this mini round, time:  1.111999273300171  iou  tensor(0.6774, device='cuda:0')
# 	For this mini round, time:  1.1220011711120605  iou  tensor(0.6845, device='cuda:0')
# 	For this mini round, time:  1.1099998950958252  iou  tensor(0.6772, device='cuda:0')
# 	For this mini round, time:  1.1170005798339844  iou  tensor(0.6876, device='cuda:0')
# 	For this mini round, time:  1.1090011596679688  iou  tensor(0.6887, device='cuda:0')
# 	For this mini round, time:  1.116999864578247  iou  tensor(0.6701, device='cuda:0')
# Time on avg:  1.1161003112792969  IOU on avg:  tensor(0.6816, device='cuda:0')
# Round  14
# Training done!  423.6875
# 	For this mini round, time:  1.1270005702972412  iou  tensor(0.6933, device='cuda:0')
# 	For this mini round, time:  1.117999792098999  iou  tensor(0.7069, device='cuda:0')
# 	For this mini round, time:  1.1160008907318115  iou  tensor(0.6859, device='cuda:0')
# 	For this mini round, time:  1.1160006523132324  iou  tensor(0.6961, device='cuda:0')
# 	For this mini round, time:  1.1180005073547363  iou  tensor(0.6907, device='cuda:0')
# 	For this mini round, time:  1.1190001964569092  iou  tensor(0.6990, device='cuda:0')
# 	For this mini round, time:  1.1160001754760742  iou  tensor(0.6907, device='cuda:0')
# 	For this mini round, time:  1.1169993877410889  iou  tensor(0.7018, device='cuda:0')
# 	For this mini round, time:  1.1179988384246826  iou  tensor(0.7012, device='cuda:0')
# 	For this mini round, time:  1.116999626159668  iou  tensor(0.6824, device='cuda:0')
# Time on avg:  1.1182000637054443  IOU on avg:  tensor(0.6948, device='cuda:0')
# Round  15
# Training done!  423.65625
# 	For this mini round, time:  1.1290006637573242  iou  tensor(0.6789, device='cuda:0')
# 	For this mini round, time:  1.1080005168914795  iou  tensor(0.6911, device='cuda:0')
# 	For this mini round, time:  1.1150002479553223  iou  tensor(0.6724, device='cuda:0')
# 	For this mini round, time:  1.1070008277893066  iou  tensor(0.6805, device='cuda:0')
# 	For this mini round, time:  1.1180033683776855  iou  tensor(0.6761, device='cuda:0')
# 	For this mini round, time:  1.1089982986450195  iou  tensor(0.6828, device='cuda:0')
# 	For this mini round, time:  1.116999864578247  iou  tensor(0.6757, device='cuda:0')
# 	For this mini round, time:  1.120999813079834  iou  tensor(0.6854, device='cuda:0')
# 	For this mini round, time:  1.1170001029968262  iou  tensor(0.6868, device='cuda:0')
# 	For this mini round, time:  1.1210007667541504  iou  tensor(0.6690, device='cuda:0')
# Time on avg:  1.1162004470825195  IOU on avg:  tensor(0.6799, device='cuda:0')
# Round  16
# Training done!  423.546875
# 	For this mini round, time:  1.1270005702972412  iou  tensor(0.6929, device='cuda:0')
# 	For this mini round, time:  1.1190013885498047  iou  tensor(0.7067, device='cuda:0')
# 	For this mini round, time:  1.1149990558624268  iou  tensor(0.6856, device='cuda:0')
# 	For this mini round, time:  1.1179993152618408  iou  tensor(0.6955, device='cuda:0')
# 	For this mini round, time:  1.1110007762908936  iou  tensor(0.6900, device='cuda:0')
# 	For this mini round, time:  1.1210014820098877  iou  tensor(0.6986, device='cuda:0')
# 	For this mini round, time:  1.1100006103515625  iou  tensor(0.6903, device='cuda:0')
# 	For this mini round, time:  1.1159989833831787  iou  tensor(0.7014, device='cuda:0')
# 	For this mini round, time:  1.1400015354156494  iou  tensor(0.7010, device='cuda:0')
# 	For this mini round, time:  1.1150000095367432  iou  tensor(0.6820, device='cuda:0')
# Time on avg:  1.1192003726959228  IOU on avg:  tensor(0.6944, device='cuda:0')
# Round  17
# Training done!  419.078125
# 	For this mini round, time:  1.1329994201660156  iou  tensor(0.7827, device='cuda:0')
# 	For this mini round, time:  1.122997760772705  iou  tensor(0.7918, device='cuda:0')
# 	For this mini round, time:  1.1200006008148193  iou  tensor(0.7833, device='cuda:0')
# 	For this mini round, time:  1.1219980716705322  iou  tensor(0.7852, device='cuda:0')
# 	For this mini round, time:  1.1679999828338623  iou  tensor(0.7828, device='cuda:0')
# 	For this mini round, time:  1.1709980964660645  iou  tensor(0.7886, device='cuda:0')
# 	For this mini round, time:  1.1259992122650146  iou  tensor(0.7872, device='cuda:0')
# 	For this mini round, time:  1.1169993877410889  iou  tensor(0.7875, device='cuda:0')
# 	For this mini round, time:  1.1250007152557373  iou  tensor(0.7883, device='cuda:0')
# 	For this mini round, time:  1.1170001029968262  iou  tensor(0.7806, device='cuda:0')
# Time on avg:  1.1321993350982666  IOU on avg:  tensor(0.7858, device='cuda:0')
# Round  18
# Training done!  424.265625
# 	For this mini round, time:  1.1370007991790771  iou  tensor(0.6931, device='cuda:0')
# 	For this mini round, time:  1.1169991493225098  iou  tensor(0.7070, device='cuda:0')
# 	For this mini round, time:  1.1250004768371582  iou  tensor(0.6858, device='cuda:0')
# 	For this mini round, time:  1.1159999370574951  iou  tensor(0.6959, device='cuda:0')
# 	For this mini round, time:  1.1230010986328125  iou  tensor(0.6904, device='cuda:0')
# 	For this mini round, time:  1.1160001754760742  iou  tensor(0.6987, device='cuda:0')
# 	For this mini round, time:  1.121999979019165  iou  tensor(0.6906, device='cuda:0')
# 	For this mini round, time:  1.1150014400482178  iou  tensor(0.7019, device='cuda:0')
# 	For this mini round, time:  1.1220006942749023  iou  tensor(0.7012, device='cuda:0')
# 	For this mini round, time:  1.115999460220337  iou  tensor(0.6822, device='cuda:0')
# Time on avg:  1.120900321006775  IOU on avg:  tensor(0.6947, device='cuda:0')
# Round  19
# Training done!  420.78125
# 	For this mini round, time:  1.133000135421753  iou  tensor(0.7411, device='cuda:0')
# 	For this mini round, time:  1.121999740600586  iou  tensor(0.7505, device='cuda:0')
# 	For this mini round, time:  1.1169993877410889  iou  tensor(0.7415, device='cuda:0')
# 	For this mini round, time:  1.1220006942749023  iou  tensor(0.7413, device='cuda:0')
# 	For this mini round, time:  1.1169989109039307  iou  tensor(0.7398, device='cuda:0')
# 	For this mini round, time:  1.121999740600586  iou  tensor(0.7516, device='cuda:0')
# 	For this mini round, time:  1.1190009117126465  iou  tensor(0.7404, device='cuda:0')
# 	For this mini round, time:  1.1190004348754883  iou  tensor(0.7489, device='cuda:0')
# 	For this mini round, time:  1.115999460220337  iou  tensor(0.7436, device='cuda:0')
# 	For this mini round, time:  1.1240012645721436  iou  tensor(0.7329, device='cuda:0')
# Time on avg:  1.1211000680923462  IOU on avg:  tensor(0.7432, device='cuda:0')
#
#
# Testing done!
#
# Training time:  422.25546875
# Testing time:  1.132250198125839
# Testing acc:  0.7248622208833695
# (array([439.625   , 423.625   , 424.109375, 421.921875, 418.125   ,
#         417.640625, 416.234375, 415.34375 , 425.625   , 416.9375  ,
#         422.171875, 422.1875  , 423.46875 , 423.078125, 423.6875  ,
#         423.65625 , 423.546875, 419.078125, 424.265625, 420.78125 ]),
#  array([1.17320061, 1.12870002, 1.1275008 , 1.13630023, 1.16820042,
#         1.19040034, 1.12610004, 1.13200009, 1.13279982, 1.12219989,
#         1.12289989, 1.12070019, 1.12010071, 1.11610031, 1.11820006,
#         1.11620045, 1.11920037, 1.13219934, 1.12090032, 1.12110007]),
#  array([0.71016449, 0.75654006, 0.72461247, 0.72426671, 0.69404417,
#         0.74259561, 0.74962711, 0.76263976, 0.77672899, 0.68542016,
#         0.77729839, 0.74367559, 0.67529362, 0.6816051 , 0.69481021,
#         0.67986947, 0.69440752, 0.78580296, 0.69467705, 0.74316496]))
